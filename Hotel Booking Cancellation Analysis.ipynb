# %% [markdown]
# # **Classification and Hypothesis Testing: Hotel Booking Cancellation Prediction**
#
#
# ---------------
#
#
# ### **Context**
#
# **A significant number of hotel bookings are called off due to cancellations or no-shows.** Typical reasons for cancellations include change of plans, scheduling conflicts, etc. This is often made easier by the option to do so free of charge or preferably at a low cost. This may be beneficial to hotel guests, but it is a less desirable and possibly revenue-diminishing factor for hotels to deal with. Such losses are particularly high on last-minute cancellations.
#
# The new technologies involving online booking channels have dramatically changed customers’ booking possibilities and behavior. This adds a further dimension to the challenge of how hotels handle cancellations, which are no longer limited to traditional booking and guest characteristics.
#
# This pattern of cancellations of bookings impacts a hotel on various fronts:
# 1. **Loss of resources (revenue)** when the hotel cannot resell the room.
# 2. **Additional costs of distribution channels** by increasing commissions or paying for publicity to help sell these rooms.
# 3. **Lowering prices last minute**, so the hotel can resell a room, resulting in reducing the profit margin.
# 4. **Human resources to make arrangements** for the guests.
#
# ### **Objective**
#
# This increasing number of cancellations calls for a Machine Learning based solution that can help in predicting which booking is likely to be canceled. INN Hotels Group has a chain of hotels in Portugal - they are facing problems with this high number of booking cancellations and have reached out to your firm for data-driven solutions. My objective is to analyze the data provided to find which factors have a high influence on booking cancellations, build a predictive model that can predict which booking is going to be canceled in advance, and help in formulating profitable policies for cancellations and refunds.
#
#
# ### **Data Description**
#
# The data contains the different attributes of customers' booking details. The detailed data dictionary is given below:
#
#
# **Data Dictionary**
#
# * **Booking_ID:** Unique identifier of each booking
# * **no_of_adults:** Number of adults
# * **no_of_children:** Number of children
# * **no_of_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# * **no_of_week_nights:** Number of weekday nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# * **type_of_meal_plan:** Type of meal plan booked by the customer:
#     * Not Selected – No meal plan selected
#     * Meal Plan 1 – Breakfast
#     * Meal Plan 2 – Half board (breakfast and one other meal)
#     * Meal Plan 3 – Full board (breakfast, lunch, and dinner)
# * **required_car_parking_space:** Does the customer require a car parking space? (0 - No, 1- Yes)
# * **room_type_reserved:** Type of room reserved by the customer. The values are ciphered (encoded) by INN Hotels.
# * **lead_time:** Number of days between the date of booking and the arrival date
# * **arrival_year:** Year of arrival date
# * **arrival_month:** Month of arrival date
# * **arrival_date:** Date of the month
# * **market_segment_type:** Market segment designation.
# * **repeated_guest:** Is the customer a repeated guest? (0 - No, 1- Yes)
# * **no_of_previous_cancellations:** Number of previous bookings that were canceled by the customer prior to the current booking
# * **no_of_previous_bookings_not_canceled:** Number of previous bookings not canceled by the customer prior to the current booking
# * **avg_price_per_room:** Average price per day of the reservation; prices of the rooms are dynamic. (in euros)
# * **no_of_special_requests:** Total number of special requests made by the customer (e.g. high floor, view from the room, etc)
# * **booking_status:** Flag indicating if the booking was canceled or not.

# %% [markdown]
# ## **Importing the libraries required**

# %%
# Importing the basic libraries I will require for the project

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# Libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Importing the required Machine Learning models from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# Importing the other required functions from Scikit-Learn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder

# To get diferent metric scores
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,plot_confusion_matrix,precision_recall_curve,roc_curve,make_scorer

# Code to ignore warnings from function usage
import warnings;
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading the dataset**

# %%
hotel = pd.read_csv("INNHotelsGroup.csv")

# %%
# Copying data to another variable to avoid any changes to original data
data = hotel.copy()

# %% [markdown]
# ## **Overview of the dataset**

# %% [markdown]
# Let's **view the first few rows and last few rows** of the dataset in order to understand its structure a little better.

# %%
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
data.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %% [markdown]
# ### **Understanding the shape of the dataset**

# %%
data.shape
# Out:
# (36275, 19)

# %% [markdown]
# * The dataset has 36275 rows and 19 columns.

# %% [markdown]
# ### **Checking the data types of the columns for the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# * `Booking_ID`, `type_of_meal_plan`, `room_type_reserved`, `market_segment_type`, and `booking_status` are of object type while rest columns are numeric in nature.
#
# * There are no null values in the dataset.

# %% [markdown]
# ### **Dropping duplicate values**

# %%
# checking for duplicate values
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are **no duplicate values** in the data.

# %% [markdown]
# ### **Dropping the unique values column**

# %% [markdown]
# **I will be dropping the Booking_ID column first before I proceed forward**, as a column with unique values will have almost no predictive power for the Machine Learning problem at hand.

# %%
data = data.drop(["Booking_ID"], axis=1)

# %%
data.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0       Meal Plan 1                           0        Room_Type 1        224
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1         48
#
# ...

# %% [markdown]
# **Checking the statistical summary of the data.**

# %%
data.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %% [markdown]
# **1- There are minimum 0 adults and maximum 4 adults, so there have been bookings with no adults.**

# %% [markdown]
# **2- The average of lead time is 85 days, which means that guests tend to book almost 3 months in advance on average. The long lead time could mean
# more
# variability and change of plans (i.e there will more changes in 3 months as compared with 3 weeks, for instance).**

# %% [markdown]
# **3- The minimum value for price per room is 0, which means that some rooms were booked for free. This variable needs to be further analyzed.**

# %% [markdown]
# **4- Maximum number of previous cancellations is 13 which means that there have been guests that had cancelled their bookings 13 times previously. Maybe these guests tend to cancel more in the future.**

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# Let's explore these variables in some more depth by observing their distributions.

# %% [markdown]
# First, the function **hist_box() function** will be defined that provides both a boxplot and a histogram in the same visual, with which I can perform univariate analysis on the columns of this dataset.

# %%
# Defining the hist_box() function
def hist_box(data,col):
  f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={'height_ratios': (0.15, 0.85)}, figsize=(12,6))
  # Adding a graph in each part
  sns.boxplot(data[col], ax=ax_box, showmeans=True)
  sns.distplot(data[col], ax=ax_hist)
  plt.show()

# %% [markdown]
# #### **Plotting the histogram and box plot for the variable `Lead Time` using the hist_box function provided.**

# %%
hist_box(data,'lead_time')

# %% [markdown]
# **It can be seen from the distribution plot that lead time is heavily right-skewed. Also, the box plot shows that there are many outliers in this feature.**

# %% [markdown]
# #### **Plotting the histogram and box plot for the variable `Average Price per Room` using the hist_box function provided**

# %%
hist_box(data,'avg_price_per_room')

# %% [markdown]
# **The box plot shows that there are many outliers for this feature. Also, the distribution plot represents a normal distribution but it is right-skewed.**

# %% [markdown]
# **Interestingly some rooms have a price equal to 0. Let's check them.**

# %%
data[data["avg_price_per_room"] == 0]
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 63                1               0                     0                  1
# 145               1               0                     0                  2
# 209               1               0                     0                  0
# 266               1               0                     0                  2
# 267               1               0                     2                  1
# ...             ...             ...                   ...                ...
# 35983             1               0                     0                  1
# 36080             1               0                     1                  1
# 36114             1               0                     0                  1
# 36217             2               0                     2                  1
# 36250             1               0                     0                  2
#
# ...

# %% [markdown]
# - There are quite a few hotel rooms which have a price equal to 0.
# - In the market segment column, it looks like many values are complementary.

# %%
data.loc[data["avg_price_per_room"] == 0, "market_segment_type"].value_counts()
# Out:
# Complementary    354
# Online           191
# Name: market_segment_type, dtype: int64

# %% [markdown]
# * It makes sense that most values with room prices equal to 0 are the rooms given as complimentary service from the hotel.
# * The rooms booked online must be a part of some promotional campaign done by the hotel.

# %%
# Calculating the 25th quantile
Q1 = data["avg_price_per_room"].quantile(0.25)

# Calculating the 75th quantile
Q3 = data["avg_price_per_room"].quantile(0.75)

# Calculating IQR
IQR = Q3 - Q1

# Calculating value of upper whisker
Upper_Whisker = Q3 + 1.5 * IQR
Upper_Whisker
# Out:
# 179.55

# %%
# assigning the outliers the value of upper whisker
data.loc[data["avg_price_per_room"] >= 500, "avg_price_per_room"] = Upper_Whisker

# %% [markdown]
# #### **Let's understand the distribution of the categorical variables**

# %% [markdown]
# **Number of Children**

# %%
sns.countplot(data['no_of_children'])
plt.show()

# %%
data['no_of_children'].value_counts(normalize=True)
# Out:
# 0     0.925624
# 1     0.044604
# 2     0.029166
# 3     0.000524
# 9     0.000055
# 10    0.000028
# Name: no_of_children, dtype: float64

# %% [markdown]
# * Customers were not travelling with children in 93% of cases.
# * There are some values in the data where the number of children is 9 or 10, which is highly unlikely.
# * These values will be replaced with the maximum value of 3 children.

# %%
# replacing 9, and 10 children with 3
data["no_of_children"] = data["no_of_children"].replace([9, 10], 3)

# %% [markdown]
# **Arrival Month**

# %%
sns.countplot(data["arrival_month"])
plt.show()

# %%
data['arrival_month'].value_counts(normalize=True)
# Out:
# 10    0.146575
# 9     0.127112
# 8     0.105114
# 6     0.088298
# 12    0.083280
# 11    0.082150
# 7     0.080496
# 4     0.075424
# 5     0.071620
# 3     0.065003
# 2     0.046975
# 1     0.027953
# Name: arrival_month, dtype: float64

# %% [markdown]
# * October is the busiest month for hotel arrivals followed by September and August. **Over 35% of all bookings**, as shown in the above table, were for one of these three months.
# * Around 14.7% of the bookings were made for an October arrival.

# %% [markdown]
# **Booking Status**

# %%
sns.countplot(data["booking_status"])
plt.show()

# %%
data['booking_status'].value_counts(normalize=True)
# Out:
# Not_Canceled    0.672364
# Canceled        0.327636
# Name: booking_status, dtype: float64

# %% [markdown]
# * 32.8% of the bookings were canceled by the customers.

# %% [markdown]
# **Let's encode Canceled bookings to 1 and Not_Canceled as 0 for further analysis**

# %%
data["booking_status"] = data["booking_status"].apply(
    lambda x: 1 if x == "Canceled" else 0
)

# %% [markdown]
# ### **Question 3: Bivariate Analysis**

# %% [markdown]
# #### **Find and visualize the correlation matrix using a heatmap**

# %%
cols_list = data.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(12, 7))
sns.heatmap(data.corr(), annot=True, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# **There is some slight corrolation between booking status and lead time, which confirms our initial assumption (in Question 1). Also, there is some slight corrolation between no of children and adults with average price per room, which makes sense (as number of guests increases, usually larger rooms are required which means more expensive rooms).**

# %% [markdown]
# **Hotel rates are dynamic and change according to demand and customer demographics. Let's see how prices vary across different market segments**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=data, x="market_segment_type", y="avg_price_per_room", palette="gist_rainbow"
)
plt.show()

# %% [markdown]
# * Rooms booked online have high variations in prices.
# * The offline and corporate room prices are almost similar.
# * Complementary market segment gets the rooms at very low prices, which makes sense.

# %% [markdown]
# A **stacked barplot()** function is defined to help analyse how the target variable varies across predictor categories.

# %%
# Defining the stacked_barplot() function
def stacked_barplot(data,predictor,target,figsize=(10,6)):
  (pd.crosstab(data[predictor],data[target],normalize='index')*100).plot(kind='bar',figsize=figsize,stacked=True)
  plt.legend(loc="lower right")
  plt.ylabel('Percentage Cancellations %')

# %% [markdown]
# #### **Plotting the stacked barplot for the variable `Market Segment Type` against the target variable `Booking Status` using the stacked_barplot  function provided.**

# %%
stacked_barplot(data,'market_segment_type', 'booking_status')

# %% [markdown]
# **The online reservations had the most number of cancelations. Complementary bookings did not have any cancellations which makes sense (i.e. the rooms were given for free). Corporate bookings had the lowest number of cancellations (after complementary)**

# %% [markdown]
# #### **Plotting the stacked barplot for the variable `Repeated Guest` against the target variable `Booking Status` using the stacked_barplot  function provided**
#
# Repeating guests are the guests who stay in the hotel often and are important to brand equity.

# %%
stacked_barplot(data,'repeated_guest','booking_status')

# %% [markdown]
# **As expected, repeated guests had much lower number of cancellations as compared to new guests, because they have prior experience staying with the hotel and there is lower probability that they would cancel their reservation.**

# %% [markdown]
# **Let's analyze the customer who stayed for at least a day at the hotel.**

# %%
stay_data = data[(data["no_of_week_nights"] > 0) & (data["no_of_weekend_nights"] > 0)]
stay_data["total_days"] = (stay_data["no_of_week_nights"] + stay_data["no_of_weekend_nights"])

stacked_barplot(stay_data, "total_days", "booking_status",figsize=(15,6))

# %% [markdown]
# * The general trend is that the chances of cancellation increase as the number of days the customer planned to stay at the hotel increases.

# %% [markdown]
# **As hotel room prices are dynamic, Let's see how the prices vary across different months**

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(y=data["avg_price_per_room"], x=data["arrival_month"], ci=None)
plt.show()

# %% [markdown]
# * The price of rooms is highest in May to September - around 115 euros per room.

# %% [markdown]
# ## **Data Preparation for Modeling**
#
# - The objective is to predict which bookings will be canceled.
# - Before I proceed to build a model, I'll have to encode categorical features.
# - I'll split the data into train and test to be able to evaluate the model that is built on the train data.

# %% [markdown]
# **Separating the independent variables (X) and the dependent variable (Y)**

# %%
X = data.drop(["booking_status"], axis=1)
Y = data["booking_status"]

X = pd.get_dummies(X, drop_first=True) # Encoding the Categorical features

# %% [markdown]
# **Splitting the data into a 70% train and 30% test set**
#
# Some classification problems can exhibit a large imbalance in the distribution of the target classes: for instance there could be several times more negative samples than positive samples. In such cases it is recommended to use the **stratified sampling** technique to ensure that relative class frequencies are approximately preserved in each train and validation fold.

# %%
# Splitting data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30,stratify=Y, random_state=1)

# %%
print("Shape of Training set : ", X_train.shape)
print("Shape of test set : ", X_test.shape)
print("Percentage of classes in training set:")
print(y_train.value_counts(normalize=True))
print("Percentage of classes in test set:")
print(y_test.value_counts(normalize=True))
# Out:
# Shape of Training set :  (25392, 27)
# Shape of test set :  (10883, 27)
# Percentage of classes in training set:
# 0    0.672377
# 1    0.327623
# Name: booking_status, dtype: float64
# Percentage of classes in test set:
# 0    0.672333
# 1    0.327667
# Name: booking_status, dtype: float64

# %% [markdown]
# ## **Model Evaluation Criterion**
#
# #### **Model can make wrong predictions as:**
#
# 1. Predicting a customer will not cancel their booking but in reality, the customer will cancel their booking.
# 2. Predicting a customer will cancel their booking but in reality, the customer will not cancel their booking.
#
# #### **Which case is more important?**
#
# Both cases are important as:
#
# * If it is predicted that a booking will not be canceled and the booking gets canceled then the hotel will lose resources and will have to bear additional costs of distribution channels.
#
# * If it is predicted that a booking will get canceled and the booking doesn't get canceled the hotel might not be able to provide satisfactory services to the customer by assuming that this booking will be canceled. This might damage brand equity.
#
#
#
# #### **How to reduce the losses?**
#
# * The hotel would want the `F1 Score` to be maximized, the greater the F1  score, the higher the chances of minimizing False Negatives and False Positives.

# %% [markdown]
# **Also, let's create a function to calculate and print the classification report and confusion matrix so that it is not required to rewrite the same code repeatedly for each model.**

# %%
# Creating metric function 
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))

    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))
    
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Not Cancelled', 'Cancelled'], yticklabels=['Not Cancelled', 'Cancelled'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# ## **Building the model**
#
# The following 4 different models will be built:
#
# - **Logistic Regression**
# - **Support Vector Machine (SVM)**
# - **Decision Tree**
# - **Random Forest**

# %% [markdown]
# ### **Logistic Regression**

# %% [markdown]
# #### **Building a Logistic Regression model (Using the sklearn library)**

# %%
# Fitting logistic regression model
lg = LogisticRegression()
lg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### **Checking the performance of the model on train and test data**

# %%
# Checking the performance on the training data
y_pred_train = lg.predict(X_train) 
metrics_score(y_train, y_pred_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86     17073
#            1       0.74      0.61      0.67      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.78      0.75      0.76     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# **The F Scores for Class 0 and 1 are 0.86 and 0.67, respectively. Also, the accuracy is 0.80 (which can be improved).**

# %% [markdown]
# Let's check the performance on the test set

# %%
# Checking the performance on the test dataset
y_pred_test = lg.predict(X_test) 
metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      7317
#            1       0.73      0.60      0.66      3566
#
#     accuracy                           0.79     10883
#    macro avg       0.77      0.74      0.75     10883
# weighted avg       0.79      0.79      0.79     10883

# %% [markdown]
# **The accuracy of the test data set is 0.79, which is very close to accuracy of training data. This means that the model is not overfitting and is generalizing well.**

# %% [markdown]
# #### **Finding the optimal threshold for the model using the Precision-Recall Curve.**
#
# Precision-Recall curves summarize the trade-off between the true positive rate and the positive predictive value for a predictive model using different probability thresholds.
#
# Let's use the Precision-Recall curve and see if I can find a **better threshold.**

# %%
# Predict_proba gives the probability of each observation belonging to each class
y_scores_lg=lg.predict_proba(X_train)

precisions_lg, recalls_lg, thresholds_lg = precision_recall_curve(y_train, y_scores_lg[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_lg, precisions_lg[:-1], 'b--', label='precision')
plt.plot(thresholds_lg, recalls_lg[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
plt.show()

# %% [markdown]
# **It can be seen that the threshold is about 0.42**

# %%
# Setting the optimal threshold
optimal_threshold = 0.42

# %% [markdown]
# #### **Checking the performance of the model on train and test data using the optimal threshold.**

# %%
# Creating confusion matrix
y_pred_train = lg.predict_proba(X_train)
metrics_score(y_train, y_pred_train[:,1]>optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84     17073
#            1       0.68      0.68      0.68      8319
#
#     accuracy                           0.79     25392
#    macro avg       0.76      0.76      0.76     25392
# weighted avg       0.79      0.79      0.79     25392

# %% [markdown]
# **The F-score values are 0.68 and 0.84, which have not improved a lot from previous model. Also, the accuracy has remained the same.**

# %% [markdown]
# Let's check the performance on the test set

# %%
y_pred_test = lg.predict_proba(X_test)
metrics_score(y_test, y_pred_test[:,1]>optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      7317
#            1       0.67      0.67      0.67      3566
#
#     accuracy                           0.79     10883
#    macro avg       0.76      0.76      0.76     10883
# weighted avg       0.79      0.79      0.79     10883

# %% [markdown]
# **The accuracy of both test and training data is 0.79, which means that the model is not overfitting. But overall, the model has not changed a lot from the previous model.**

# %% [markdown]
# ### **Support Vector Machines**

# %% [markdown]
# To accelerate SVM training, let's scale the data for support vector machines.

# %%
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train_scaled = scaling.transform(X_train)
X_test_scaled = scaling.transform(X_test)

# %% [markdown]
# Let's build the models using the two of the widely used kernel functions:
#
# 1.   **Linear Kernel**
# 2.   **RBF Kernel**

# %% [markdown]
# #### **Building a Support Vector Machine model using a linear kernel**

# %%
svm = SVC(kernel='linear',probability=True) # Linear kernal or linear decision boundary
model = svm.fit(X_train_scaled, y_train)

# %% [markdown]
# #### **Checking the performance of the model on train and test data**

# %%
y_pred_train_svm = model.predict(X_train_scaled)
metrics_score(y_train, y_pred_train_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86     17073
#            1       0.74      0.61      0.67      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.79      0.76      0.77     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# **The accuracy has remained almost the same as compared to Logistic Regression. F Scores are also similar. However, the recall value for Class 0 and precision for Class 1 has increased. Recalls are associated with false negatives and precisions are associated with false positives.**

# %% [markdown]
# Checking model performance on test set

# %%
y_pred_test_svm = model.predict(X_test_scaled)
metrics_score(y_test, y_pred_test_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      7317
#            1       0.74      0.61      0.67      3566
#
#     accuracy                           0.80     10883
#    macro avg       0.78      0.75      0.76     10883
# weighted avg       0.80      0.80      0.80     10883

# %% [markdown]
# **The test data shows accuracy of 0.80 which is the same as training data, so the model is not overfitting.**

# %% [markdown]
# #### **Finding the optimal threshold for the model using the Precision-Recall Curve.**

# %%
# Predict on train data
y_scores_svm=model.predict_proba(X_train_scaled)

precisions_svm, recalls_svm, thresholds_svm = precision_recall_curve(y_train, y_scores_svm[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_svm, precisions_svm[:-1], 'b--', label='precision')
plt.plot(thresholds_svm, recalls_svm[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
plt.show()

# %% [markdown]
# **The threshold appears to be about 0.41**

# %%
optimal_threshold_svm=0.41

# %% [markdown]
# #### **Checking the performance of the model on train and test data using the optimal threshold.**

# %%
y_pred_train_svm = model.predict_proba(X_train_scaled)
metrics_score(y_train, y_pred_train_svm[:,1]>optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     17073
#            1       0.70      0.70      0.70      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.78      0.78      0.78     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# **The accuracy has remained the same but the FScore for Class 1 has improved slightly (from 0.67 to 0.70)**

# %%
y_pred_test = model.predict_proba(X_test_scaled)
metrics_score(y_test,y_pred_test[:,1]>optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      7317
#            1       0.70      0.69      0.69      3566
#
#     accuracy                           0.80     10883
#    macro avg       0.77      0.77      0.77     10883
# weighted avg       0.80      0.80      0.80     10883

# %% [markdown]
# **The accuracy and Fscores are the same for test and train data, meaninig that the model is not overfitting.**

# %% [markdown]
# #### **Building a Support Vector Machines model using an RBF kernel**

# %%
svm_rbf=SVC(kernel='rbf',probability=True)
svm_rbf.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True)

# %% [markdown]
# #### **Checking the performance of the model on train and test data**

# %%
y_pred_train_svm = svm_rbf.predict(X_train_scaled)
metrics_score(y_train, y_pred_train_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88     17073
#            1       0.79      0.65      0.71      8319
#
#     accuracy                           0.83     25392
#    macro avg       0.81      0.78      0.80     25392
# weighted avg       0.82      0.83      0.82     25392

# %% [markdown]
# **In the RBF kernel, almost all the parameters have increased. The accuracy has increased from 0.80 (linear kernel) to 0.83 (rbf kernel). Also, the F Scores have increased slightly (from 85 and 70 to 88 and 71). So it appears that this kernel provides better results.**

# %% [markdown]
# #### Checking model performance on test set

# %%
y_pred_test = svm_rbf.predict(X_test_scaled)

metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      7317
#            1       0.78      0.63      0.70      3566
#
#     accuracy                           0.82     10883
#    macro avg       0.81      0.77      0.78     10883
# weighted avg       0.82      0.82      0.81     10883

# %% [markdown]
# **Since the accuracy and F scores of test and training data are the same, this model is not over fitting.**

# %%
# Predict on train data
y_scores_svm=svm_rbf.predict_proba(X_train_scaled)

precisions_svm, recalls_svm, thresholds_svm = precision_recall_curve(y_train, y_scores_svm[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_svm, precisions_svm[:-1], 'b--', label='precision')
plt.plot(thresholds_svm, recalls_svm[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
plt.show()

# %%
optimal_threshold_svm=0.40

# %% [markdown]
# #### **Checking the performance of the model on train and test data using the optimal threshold.**

# %%
y_pred_train_svm = model.predict_proba(X_train_scaled)
metrics_score(y_train, y_pred_train_svm[:,1]>optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85     17073
#            1       0.69      0.71      0.70      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.78      0.78      0.78     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# **The precision for Class 1 has decreased (from 78 to 61) while the recall for this class has increased from 63 to 71. Thus, this is a better model for identifying false negatives.**

# %%
y_pred_test = svm_rbf.predict_proba(X_test_scaled)
metrics_score(y_test, y_pred_test[:,1]>optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      7317
#            1       0.71      0.73      0.72      3566
#
#     accuracy                           0.82     10883
#    macro avg       0.79      0.79      0.79     10883
# weighted avg       0.82      0.82      0.82     10883

# %% [markdown]
# **The accuracy and F score of test data and training data are very similar, therefore, the model is generalizing well.**

# %% [markdown]
# ### **Decision Trees**

# %% [markdown]
# #### **Building a Decision Tree Model**

# %%
model_dt = tree.DecisionTreeClassifier(random_state = 0, criterion = 'entropy')
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# #### **Checking the performance of the model on train and test data**

# %%
# Checking performance on the training dataset
pred_train_dt = model_dt.predict(X_train)
metrics_score(y_train, pred_train_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     17073
#            1       1.00      0.99      0.99      8319
#
#     accuracy                           0.99     25392
#    macro avg       1.00      0.99      0.99     25392
# weighted avg       0.99      0.99      0.99     25392

# %% [markdown]
# **All the parameters including F scores, accuracy, precision and recalls have significantly improved. Since these parameters are now equal to 1, it is important to check the test data to ensure the model is not overfitting.**

# %% [markdown]
# #### Checking model performance on test set

# %%
pred_test_dt = model_dt.predict(X_test)
metrics_score(y_test, pred_test_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      7317
#            1       0.80      0.79      0.79      3566
#
#     accuracy                           0.87     10883
#    macro avg       0.85      0.85      0.85     10883
# weighted avg       0.87      0.87      0.87     10883

# %% [markdown]
# **The accuracy of the test data is 0.87, as compared to 0.99 of training data. This suggests that there is some overfitting in the training model. Also, the F scores, precision and recalls have decresed in the test data, which suggests the same.**

# %% [markdown]
#  #### **Performing hyperparameter tuning for the decision tree model using GridSearch CV**

# %%
# Choose the type of classifier.
estimator = DecisionTreeClassifier(random_state = 1)

# Grid of parameters to choose from
parameters = {
    "max_depth": np.arange(2, 7, 2),
    "max_leaf_nodes": [50, 75, 150, 250],
    "min_samples_split": [10, 30, 50, 70],
}


# Run the grid search
grid_obj = GridSearchCV(estimator, parameters, cv=10)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
estimator = grid_obj.best_estimator_

# Fit the best algorithm to the data.
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, max_leaf_nodes=50, min_samples_split=10,
#                        random_state=1)

# %% [markdown]
# #### **Checking the performance of the model on the train and test data using the tuned model**

# %% [markdown]
# #### Checking performance on the training set

# %%
# Checking performance on the training dataset
dt_tuned = estimator.predict(X_train)
metrics_score(y_train, dt_tuned)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89     17073
#            1       0.82      0.68      0.75      8319
#
#     accuracy                           0.85     25392
#    macro avg       0.84      0.81      0.82     25392
# weighted avg       0.85      0.85      0.84     25392

# %% [markdown]
# **As compared with model with default parameters, the precision for Class 0 and Recall for Class 1 have increased, but precision for Class 1 and Recall for Class 0 have decreased. Lower precision for Class 1 indicates that this model will perform poorly on false positives, i.e. when the guests will cancel booking but the model predicts no cancellation. Also, the F Score (for class 0) and accuracy have decreased in this model.**

# %%
# Checking performance on the training dataset
y_pred_tuned = estimator.predict(X_test)
metrics_score(y_test, y_pred_tuned)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      7317
#            1       0.82      0.67      0.74      3566
#
#     accuracy                           0.84     10883
#    macro avg       0.84      0.80      0.81     10883
# weighted avg       0.84      0.84      0.84     10883

# %% [markdown]
# **The parameters of the test and training data are the same, which means that there is no overfitting. This makes sense since by tuning parameters I am also trying to avoid overfitting.**

# %% [markdown]
# #### **Visualizing the Decision Tree**

# %%
feature_names = list(X_train.columns)
plt.figure(figsize=(20, 10))
out = tree.plot_tree(
    estimator,max_depth=3,
    feature_names=feature_names,
    filled=True,
    fontsize=9,
    node_ids=False,
    class_names=None,
)
# below code will add arrows to the decision tree split if they are missing
for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor("black")
        arrow.set_linewidth(1)
plt.show()

# %% [markdown]
# #### **What are some important features based on the tuned decision tree?**

# %%
# Importance of features in the tree building

importances = estimator.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(8, 8))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# **As can be seen from the above chart, lead time is the most important parameter for determining cancellations. After that, number of special requests and Online bookings have the highest impacts for determining cancellations.**

# %% [markdown]
# ___

# %% [markdown]
# ### **Random Forest**

# %% [markdown]
# #### **Building a Random Forest Model**

# %%
rf_estimator = RandomForestClassifier(random_state = 1)

rf_estimator.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %% [markdown]
# #### **Checking the performance of the model on the train and test data**

# %%
y_pred_train_rf = rf_estimator.predict(X_train)

metrics_score(y_train, y_pred_train_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     17073
#            1       1.00      0.99      0.99      8319
#
#     accuracy                           0.99     25392
#    macro avg       0.99      0.99      0.99     25392
# weighted avg       0.99      0.99      0.99     25392

# %% [markdown]
# **The random forest model is providing very good parameters. All parameters have increased as compared to decision tree including accuracy and F Scores. Since these parameters are close to 1, It is better to check the test data as well.**

# %%
y_pred_test_rf = rf_estimator.predict(X_test)

metrics_score(y_test, y_pred_test_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      7317
#            1       0.88      0.80      0.84      3566
#
#     accuracy                           0.90     10883
#    macro avg       0.90      0.88      0.88     10883
# weighted avg       0.90      0.90      0.90     10883

# %% [markdown]
# **All the parameters have decreased as compared to training data, which suggests some overfitting. However, accuracy of 0.90 is still a good parameter. Also, F scores are 0.93 and 0.84 which are good (although there is overfitting).**

# %% [markdown]
# #### **What are some important features based on the Random Forest?**

# %% [markdown]
# Let's check the feature importance of the Random Forest

# %%
importances = rf_estimator.feature_importances_

columns = X.columns

importance_df = pd.DataFrame(importances, index= columns, columns=['Importance']).sort_values(by='Importance',ascending=False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_df.Importance, importance_df.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# **As shown above, the top three important features of random forest are lead_time, price per room and number of special requests. These three features are the same as the top three features of decision tree.**

# %% [markdown]
# ### **Recommending five key takeaways for business**

# %% [markdown]
# **1- Clearly, the lead time is the most important factor to be considered when detecting cancellations. The longer the lead times (i.e. the earlier the bookings), the higher chance of the booking being cancelled (and vice versa). Thus, the hotel can prioritize shorter-lead time bookings over longer ones.**

# %% [markdown]
# **2- As observed earlier, the duration of bookings are related to the cancellation rate as well, so that longer bookings have a higher chance of being cancelled as compared to shorter bookings. Therefore, the hotel can focus on short-term bookings as compared to long-term ones.**

# %% [markdown]
# **3- The bookings that were made by repeated guests have a lower chance of being cancelled. So the hotel can send promotions to repeated guests to attract them for more business, and provide them with more flexible cancellation policies because they tend to not cancel the bookings after all.**

# %% [markdown]
# **4- Also, number of scpecial requests is observed as an important factor in both decision tree and random forest models. This would mean that the hotel should give higher chance of cancellation to bookings that have made special requests. This makes sense because these bookings could involve individuals with small children (i.e. special request for a child bed) in which case their plans can easily change based on child's situation.**

# %% [markdown]
# **5- The hotel has focused on F1 Scores. Based on this, the Logistics Regression seems to give lower F1 Scores as compared to Decision tree and Random forest models. This indicates that this problem is better defined with non-linear models rather than linear models. So the hotel can use either Random forest or Decision tree model (with default parameters) to predict future cancellations.**
